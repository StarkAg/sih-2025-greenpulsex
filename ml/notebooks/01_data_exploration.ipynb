# %% [markdown]
# # GreenPulseX - Data Exploration
#
# This notebook explores the sensor data and yield patterns for crop yield prediction.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# Set style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)
